# %%
# !pip install -Uqq fastai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 29.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 838.7 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 71.7 MB/s eta 0:00:00

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/BirdRecognizer
# Out:
# /content/drive/My Drive/BirdRecognizer

# %%
version = 2
img_path = 'test_images'
model_path = f'models/cap-recognizer-v{version}.pkl'

# %%
model = load_learner(model_path)

# %%
img = Image.open(f'{img_path}/firstpic.jpeg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/firstpic.jpeg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Robin',
#  tensor(14),
#  tensor([1.6878e-05, 5.0876e-07, 2.1575e-05, 5.3509e-07, 2.2831e-06, 1.4536e-06,
#          3.1607e-06, 7.3835e-06, 4.9013e-06, 8.2736e-06, 3.6136e-06, 1.3483e-06,
#          2.4321e-06, 2.8471e-06, 9.9933e-01, 2.6222e-06, 5.6128e-04, 1.7838e-05,
#          9.7700e-06, 3.5830e-07]))

# %%
img = Image.open(f'{img_path}/secondpic.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=67x128>

# %%
model.predict(f'{img_path}/secondpic.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Parrot',
#  tensor(9),
#  tensor([1.4763e-07, 2.1504e-09, 1.8432e-08, 3.6580e-07, 9.1314e-09, 5.4105e-08,
#          1.9867e-08, 2.4485e-08, 2.6706e-08, 1.0000e+00, 5.2897e-09, 1.8267e-08,
#          3.3109e-09, 5.8764e-09, 1.4455e-08, 1.5993e-10, 1.5619e-08, 6.4159e-09,
#          5.3455e-10, 5.3983e-09]))

# %%
img = Image.open(f'{img_path}/thirdpic.jpeg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model.predict(f'{img_path}/thirdpic.jpeg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Sparrow',
#  tensor(16),
#  tensor([2.9970e-06, 4.8667e-06, 1.6817e-05, 1.6042e-07, 1.3056e-04, 1.7521e-07,
#          1.8060e-06, 9.5855e-07, 9.8162e-06, 5.0565e-06, 3.1339e-06, 2.8281e-07,
#          3.0741e-07, 2.7486e-05, 1.7911e-05, 7.9168e-07, 9.9976e-01, 1.1399e-06,
#          8.5489e-06, 2.4769e-06]))
